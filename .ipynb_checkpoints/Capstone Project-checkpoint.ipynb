# %% [markdown]
# # My Capstone Project
#
# This notebook is my assignment for the IBM Data Science Capstone project
#
# ## Project 1

# %%
import pandas as pd
import numpy as np

# %%
print ("Hello Capstone Project Course")
# Out:
# Hello Capstone Project Course

# %% [markdown]
# <a id="Q1"></a><hr>
# ## Project 2

# %%
from bs4 import BeautifulSoup
import urllib
import math

url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
content = urllib.request.urlopen(url).read()
soup = BeautifulSoup(content)

table = soup.find('table', attrs={'class':'wikitable sortable'})
table_rows = table.find_all('tr')

l = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    if len(row) == 3:  # Eliminate bogus rows
        if row[1] != 'Not assigned' and len(row[1]) > 0:  # Remove where borough is not assigned
            row[2] = row[2].strip("\n")  # Strip carriage return on neighborhood
            if row[2] == 'Not assigned': # Set not assigned neighborhoods to borough name
                row[2] = row[1]
            l.append(row)

# Convert list to datafram
ton1 = pd.DataFrame(l, columns=['PostalCode','Borough','Neighborhood'])

# Next line comcatenates the common borough strings
ton2 = ton1.groupby(['PostalCode','Borough'])['Neighborhood'].apply(', '.join).to_frame().reset_index()
ton2.shape
# Out:
# (103, 3)

# %%
ton2
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A      Queen's Park
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A  Downtown Toronto
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                       Rouge, Malvern  43.811525 -79.195517
# 1               Highland Creek, Rouge Hill, Port Union  43.785665 -79.158725
# 2                    Guildwood, Morningside, West Hill  43.765815 -79.175193
# 3                                               Woburn  43.768369 -79.217590
# 4                                            Cedarbrae  43.769688 -79.239440
# 5                                  Scarborough Village  43.743125 -79.231750
# 6          East Birchmount Park, Ionview, Kennedy Park  43.726276 -79.263625
# 7                      Clairlea, Golden Mile, Oakridge  43.713054 -79.285055
# 8      Cliffcrest, Cliffside, Scarborough Village West  43.724235 -79.227925
# 9                          Birch Cliff, Cliffside West  43.696770 -79.259967
# 10   Dorset Park, Scarborough Town Centre, Wexford ...  43.759975 -79.268974
# 11                                   Maryvale, Wexford  43.750710 -79.300560
# 12                                           Agincourt  43.793940 -79.267976
# 13             Clarks Corners, Sullivan, Tam O'Shanter  43.784725 -79.299066
# 14   Agincourt North, L'Amoreaux East, Milliken, St...  43.817685 -79.280187
# 15                                     L'Amoreaux West  43.800883 -79.320740
# 16                                         Upper Rouge  43.834215 -79.216701
# 17                                   Hillcrest Village  43.802845 -79.356207
# 18                        Fairview, Henry Farm, Oriole  43.780970 -79.347813
# 19                                     Bayview Village  43.781015 -79.380529
# 20                            Silver Hills, York Mills  43.757095 -79.380320
# 21                             Newtonbrook, Willowdale  43.791475 -79.413605
# 22                                    Willowdale South  43.768165 -79.407420
# 23                                     York Mills West  43.747895 -79.399919
# 24                                     Willowdale West  43.777695 -79.445797
# 25                                           Parkwoods  43.752420 -79.329242
# 26                                     Don Mills North  43.749055 -79.362227
# 27                    Flemingdon Park, Don Mills South  43.721425 -79.343454
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.757875 -79.448688
# 29                     Northwood Park, York University  43.764765 -79.488094
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.692105 -79.430355
# 74                                 Caledonia-Fairbanks  43.688640 -79.451018
# 75                                            Christie  43.668781 -79.420710
# 76                        Dovercourt Village, Dufferin  43.665087 -79.438705
# 77                            Little Portugal, Trinity  43.648525 -79.417757
# 78        Brockton, Exhibition Place, Parkdale Village  43.639410 -79.424362
# 79                  Downsview, North Park, Upwood Park  43.713810 -79.488301
# 80      Del Ray, Keelesdale, Mount Dennis, Silverthorn  43.694530 -79.484489
# 81                       The Junction North, Runnymede  43.676125 -79.481932
# 82                       High Park, The Junction South  43.659935 -79.463019
# 83                              Parkdale, Roncesvalles  43.647870 -79.449776
# 84                                  Runnymede, Swansea  43.649192 -79.467990
# 85                                        Queen's Park  43.660670 -79.390850
# 86               Canada Post Gateway Processing Centre  43.645406 -79.617668
# 87   Business Reply Mail Processing Centre 969 Eastern  43.648690 -79.385440
# 88        Humber Bay Shores, Mimico South, New Toronto  43.612200 -79.495146
# 89                              Alderwood, Long Branch  43.601131 -79.538785
# 90       The Kingsway, Montgomery Road, Old Mill North  43.653760 -79.510890
# 91   Humber Bay, King's Mill Park, Kingsway Park So...  43.632835 -79.489550
# 92   Kingsway Park South West, Mimico NW, The Queen...  43.624630 -79.526950
# 93                                        Queen's Park  43.662299 -79.528195
# 94   Cloverdale, Islington, Martin Grove, Princess ...  43.650347 -79.555040
# 95   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.648573 -79.578250
# 96                                       Humber Summit  43.759500 -79.557028
# 97                                    Emery, Humberlea  43.733705 -79.537508
# 98                                              Weston  43.704845 -79.517546
# 99                                           Westmount  43.696505 -79.530252
# 100  Kingsview Village, Martin Grove Gardens, Richv...  43.686810 -79.557284
# 101  Albion Gardens, Beaumond Heights, Humbergate, ...  43.743145 -79.584664
# 102                                          Northwest  43.711740 -79.579181
#
# [103 rows x 5 columns]

# %% [markdown]
# <a id="Q2"></a><hr>
# **Code related to question #2**

# %%
import geocoder 

lat = []
long = []
for index, row in ton2.iterrows(): # Create a list of latitude and longitude
    g = geocoder.arcgis(row[1]+', Ontario, '+row[0])  # I preferred the arcgis provider
    if g.ok: # When postalcode helped
        lat.append(g.latlng[0])
        long.append(g.latlng[1])
    else:  # When postalcode didn't have a result
        g = geocoder.arcgis(row[1]+', Ontario')
        lat.append(g.latlng[0])
        long.append(g.latlng[1])
    
# Add values to dataframe
ton2['Latitude'] = lat
ton2['Longitude'] = long

ton2.shape
# Out:
# (103, 5)

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(ton2['Borough'].unique()),
        ton2.shape[0]
    )
)
# Out:
# The dataframe has 11 boroughs and 103 neighborhoods.

# %%
ton2
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A      Queen's Park
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A  Downtown Toronto
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                       Rouge, Malvern  43.811525 -79.195517
# 1               Highland Creek, Rouge Hill, Port Union  43.785665 -79.158725
# 2                    Guildwood, Morningside, West Hill  43.765815 -79.175193
# 3                                               Woburn  43.768369 -79.217590
# 4                                            Cedarbrae  43.769688 -79.239440
# 5                                  Scarborough Village  43.743125 -79.231750
# 6          East Birchmount Park, Ionview, Kennedy Park  43.726276 -79.263625
# 7                      Clairlea, Golden Mile, Oakridge  43.713054 -79.285055
# 8      Cliffcrest, Cliffside, Scarborough Village West  43.724235 -79.227925
# 9                          Birch Cliff, Cliffside West  43.696770 -79.259967
# 10   Dorset Park, Scarborough Town Centre, Wexford ...  43.759975 -79.268974
# 11                                   Maryvale, Wexford  43.750710 -79.300560
# 12                                           Agincourt  43.793940 -79.267976
# 13             Clarks Corners, Sullivan, Tam O'Shanter  43.784725 -79.299066
# 14   Agincourt North, L'Amoreaux East, Milliken, St...  43.817685 -79.280187
# 15                                     L'Amoreaux West  43.800883 -79.320740
# 16                                         Upper Rouge  43.834215 -79.216701
# 17                                   Hillcrest Village  43.802845 -79.356207
# 18                        Fairview, Henry Farm, Oriole  43.780970 -79.347813
# 19                                     Bayview Village  43.781015 -79.380529
# 20                            Silver Hills, York Mills  43.757095 -79.380320
# 21                             Newtonbrook, Willowdale  43.791475 -79.413605
# 22                                    Willowdale South  43.768165 -79.407420
# 23                                     York Mills West  43.747895 -79.399919
# 24                                     Willowdale West  43.777695 -79.445797
# 25                                           Parkwoods  43.752420 -79.329242
# 26                                     Don Mills North  43.749055 -79.362227
# 27                    Flemingdon Park, Don Mills South  43.721425 -79.343454
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.757875 -79.448688
# 29                     Northwood Park, York University  43.764765 -79.488094
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.692105 -79.430355
# 74                                 Caledonia-Fairbanks  43.688640 -79.451018
# 75                                            Christie  43.668781 -79.420710
# 76                        Dovercourt Village, Dufferin  43.665087 -79.438705
# 77                            Little Portugal, Trinity  43.648525 -79.417757
# 78        Brockton, Exhibition Place, Parkdale Village  43.639410 -79.424362
# 79                  Downsview, North Park, Upwood Park  43.713810 -79.488301
# 80      Del Ray, Keelesdale, Mount Dennis, Silverthorn  43.694530 -79.484489
# 81                       The Junction North, Runnymede  43.676125 -79.481932
# 82                       High Park, The Junction South  43.659935 -79.463019
# 83                              Parkdale, Roncesvalles  43.647870 -79.449776
# 84                                  Runnymede, Swansea  43.649192 -79.467990
# 85                                        Queen's Park  43.660670 -79.390850
# 86               Canada Post Gateway Processing Centre  43.645406 -79.617668
# 87   Business Reply Mail Processing Centre 969 Eastern  43.648690 -79.385440
# 88        Humber Bay Shores, Mimico South, New Toronto  43.612200 -79.495146
# 89                              Alderwood, Long Branch  43.601131 -79.538785
# 90       The Kingsway, Montgomery Road, Old Mill North  43.653760 -79.510890
# 91   Humber Bay, King's Mill Park, Kingsway Park So...  43.632835 -79.489550
# 92   Kingsway Park South West, Mimico NW, The Queen...  43.624630 -79.526950
# 93                                        Queen's Park  43.662299 -79.528195
# 94   Cloverdale, Islington, Martin Grove, Princess ...  43.650347 -79.555040
# 95   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.648573 -79.578250
# 96                                       Humber Summit  43.759500 -79.557028
# 97                                    Emery, Humberlea  43.733705 -79.537508
# 98                                              Weston  43.704845 -79.517546
# 99                                           Westmount  43.696505 -79.530252
# 100  Kingsview Village, Martin Grove Gardens, Richv...  43.686810 -79.557284
# 101  Albion Gardens, Beaumond Heights, Humbergate, ...  43.743145 -79.584664
# 102                                          Northwest  43.711740 -79.579181
#
# [103 rows x 5 columns]

# %% [markdown]
# <a id="Q3"> </a><hr>
# **Code related to question #3**

# %%
from geopy.geocoders import Nominatim
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
CLIENT_ID = 'removed' # your Foursquare ID
CLIENT_SECRET = 'removed' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
import requests
LIMIT = 100
radius = 500

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)   
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)       
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items'] 
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    return(nearby_venues)

toronto_venues = getNearbyVenues(names=ton2['Neighborhood'],
                                   latitudes=ton2['Latitude'],
                                   longitudes=ton2['Longitude'])

print(toronto_venues.shape)
toronto_venues.head()
# Out:
# Rouge, Malvern
# Highland Creek, Rouge Hill, Port Union
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# East Birchmount Park, Ionview, Kennedy Park
# Clairlea, Golden Mile, Oakridge
# Cliffcrest, Cliffside, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Scarborough Town Centre, Wexford Heights
# Maryvale, Wexford
# Agincourt
# Clarks Corners, Sullivan, Tam O'Shanter
# Agincourt North, L'Amoreaux East, Milliken, Steeles East
# L'Amoreaux West
# Upper Rouge
# Hillcrest Village
# Fairview, Henry Farm, Oriole
# Bayview Village
# Silver Hills, York Mills
# Newtonbrook, Willowdale
# Willowdale South
# York Mills West
# Willowdale West
# Parkwoods
# Don Mills North
# Flemingdon Park, Don Mills South
# Bathurst Manor, Downsview North, Wilson Heights
# Northwood Park, York University
# CFB Toronto, Downsview East
# Downsview West
# Downsview Central
# Downsview Northwest
# Victoria Village
# Woodbine Gardens, Parkview Hill
# Woodbine Heights
# The Beaches
# Leaside
# Thorncliffe Park
# East Toronto
# The Danforth West, Riverdale
# The Beaches West, India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park, Summerhill East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# Rosedale
# Cabbagetown, St. James Town
# Church and Wellesley
# Harbourfront
# Ryerson, Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide, King, Richmond
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Commerce Court, Victoria Hotel
# Bedford Park, Lawrence Manor East
# Roselawn
# Forest Hill North, Forest Hill West
# The Annex, North Midtown, Yorkville
# Harbord, University of Toronto
# Chinatown, Grange Park, Kensington Market
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place, Underground city
# Lawrence Heights, Lawrence Manor
# Glencairn
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Christie
# Dovercourt Village, Dufferin
# Little Portugal, Trinity
# Brockton, Exhibition Place, Parkdale Village
# Downsview, North Park, Upwood Park
# Del Ray, Keelesdale, Mount Dennis, Silverthorn
# The Junction North, Runnymede
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Queen's Park
# Canada Post Gateway Processing Centre
# Business Reply Mail Processing Centre 969 Eastern
# Humber Bay Shores, Mimico South, New Toronto
# Alderwood, Long Branch
# The Kingsway, Montgomery Road, Old Mill North
# Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea
# Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor
# Queen's Park
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
# Humber Summit
# Emery, Humberlea
# Weston
# Westmount
# Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown
# Northwest
# (2360, 7)
#                              Neighborhood  Neighborhood Latitude  \
# 0                          Rouge, Malvern              43.811525
# 1  Highland Creek, Rouge Hill, Port Union              43.785665
# 2  Highland Creek, Rouge Hill, Port Union              43.785665
# 3  Highland Creek, Rouge Hill, Port Union              43.785665
# 4       Guildwood, Morningside, West Hill              43.765815
#
#    Neighborhood Longitude                      Venue  Venue Latitude  \
# 0              -79.195517   Straits Aqualife Limited       43.809268
# 1              -79.158725  Affordable Toronto Movers       43.787919
# 2              -79.158725     Chris Effects Painting       43.784343
# 3              -79.158725      Royal Canadian Legion       43.782533
# 4              -79.175193   Homestead Roofing Repair       43.765140
#
#    Venue Longitude              Venue Category
# 0       -79.199399                   Pet Store
# 1       -79.162977               Moving Target
# 2       -79.163742  Construction & Landscaping
# 3       -79.163085                         Bar
# 4       -79.178663  Construction & Landscaping

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# Create totals
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

print(toronto_onehot.shape)
print(toronto_grouped.shape)
# Out:
# (2360, 264)
# (100, 264)

# %%
# For information purposes only
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 4})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adelaide, King, Richmond----
#               venue  freq
# 0       Coffee Shop  0.08
# 1              Café  0.06
# 2             Hotel  0.05
# 3        Steakhouse  0.04
# 4  Asian Restaurant  0.03
#
#
# ----Agincourt----
#               venue    freq
# 0       Supermarket  0.1429
# 1     Shopping Mall  0.1429
# 2            Bakery  0.0714
# 3  Department Store  0.0714
# 4  Sushi Restaurant  0.0714
#
#
# ----Agincourt North, L'Amoreaux East, Milliken, Steeles East----
#                        venue  freq
# 0                   Pharmacy   1.0
# 1                Yoga Studio   0.0
# 2               Noodle House   0.0
# 3         Mexican Restaurant   0.0
# 4  Middle Eastern Restaurant   0.0
#
#
# ----Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown----
#                  venue    freq
# 0        Grocery Store  0.1429
# 1                 Park  0.0714
# 2             Pharmacy  0.0714
# 3         Liquor Store  0.0714
# 4  Fried Chicken Joint  0.0714
#
#
# ----Alderwood, Long Branch----
#                venue  freq
# 0                Gym   0.2
# 1  Convenience Store   0.2
# 2                Pub   0.2
# 3     Sandwich Place   0.2
# 4       Dance Studio   0.2
#
#
# ----Bathurst Manor, Downsview North, Wilson Heights----
#                        venue  freq
# 0                Men's Store   1.0
# 1                Yoga Studio   0.0
# 2         Mexican Restaurant   0.0
# 3  Middle Eastern Restaurant   0.0
# 4         Miscellaneous Shop   0.0
#
#
# ----Bayview Village----
#                         venue  freq
# 0                        Park   0.2
# 1  Construction & Landscaping   0.2
# 2          Golf Driving Range   0.2
# 3                     Dog Run   0.2
# 4                       Trail   0.2
#
#
# ----Bedford Park, Lawrence Manor East----
#                 venue    freq
# 0    Sushi Restaurant  0.0952
# 1         Coffee Shop  0.0952
# 2  Italian Restaurant  0.0952
# 3          Hobby Shop  0.0476
# 4     Thai Restaurant  0.0476
#
#
# ----Berczy Park----
#             venue    freq
# 0     Coffee Shop  0.0820
# 1      Restaurant  0.0492
# 2    Cocktail Bar  0.0328
# 3        Beer Bar  0.0328
# 4  Breakfast Spot  0.0328
#
#
# ----Birch Cliff, Cliffside West----
#                    venue    freq
# 0                   Park  0.1667
# 1  General Entertainment  0.1667
# 2        College Stadium  0.1667
# 3               Gym Pool  0.1667
# 4           Skating Rink  0.1667
#
#
# ----Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe----
#                 venue    freq
# 0       Shopping Mall  0.1667
# 1  College Rec Center  0.1667
# 2   Electronics Store  0.1667
# 3       Grocery Store  0.1667
# 4        Carpet Store  0.1667
#
#
# ----Brockton, Exhibition Place, Parkdale Village----
#                     venue    freq
# 0             Coffee Shop  0.0923
# 1              Restaurant  0.0615
# 2  Furniture / Home Store  0.0615
# 3                    Café  0.0615
# 4          Sandwich Place  0.0462
#
#
# ----Business Reply Mail Processing Centre 969 Eastern----
#          venue  freq
# 0  Coffee Shop  0.10
# 1         Café  0.04
# 2   Steakhouse  0.04
# 3          Bar  0.04
# 4        Hotel  0.04
#
#
# ----CFB Toronto, Downsview East----
#          venue  freq
# 0  Coffee Shop  0.25
# 1   Food Court  0.25
# 2      Airport  0.25
# 3         Park  0.25
# 4  Yoga Studio  0.00
#
#
# ----CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara----
#                venue  freq
# 0        Coffee Shop  0.06
# 1              Hotel  0.05
# 2   Sushi Restaurant  0.04
# 3         Restaurant  0.04
# 4  French Restaurant  0.03
#
#
# ----Cabbagetown, St. James Town----
#          venue    freq
# 0  Coffee Shop  0.1053
# 1   Restaurant  0.0789
# 2       Bakery  0.0526
# 3         Café  0.0526
# 4  Pizza Place  0.0526
#
#
# ----Caledonia-Fairbanks----
#                   venue  freq
# 0                  Park   0.2
# 1         Women's Store   0.1
# 2  Fast Food Restaurant   0.1
# 3    Mexican Restaurant   0.1
# 4            Beer Store   0.1
#
#
# ----Canada Post Gateway Processing Centre----
#             venue    freq
# 0           Hotel  0.2857
# 1        Pharmacy  0.1429
# 2     Coffee Shop  0.1429
# 3             Gym  0.1429
# 4  Sandwich Place  0.1429
#
#
# ----Cedarbrae----
#                      venue  freq
# 0               Playground   0.5
# 1                    Trail   0.5
# 2            Movie Theater   0.0
# 3                Nightclub   0.0
# 4  New American Restaurant   0.0
#
#
# ----Central Bay Street----
#                   venue    freq
# 0           Coffee Shop  0.1212
# 1        Clothing Store  0.0606
# 2              Tea Room  0.0303
# 3        Cosmetics Shop  0.0303
# 4  Fast Food Restaurant  0.0303
#
#
# ----Chinatown, Grange Park, Kensington Market----
#                  venue   freq
# 0                 Café  0.075
# 1  Dumpling Restaurant  0.050
# 2                  Bar  0.050
# 3   Mexican Restaurant  0.050
# 4   Chinese Restaurant  0.050
#
#
# ----Christie----
#            venue    freq
# 0           Café  0.2727
# 1  Grocery Store  0.1818
# 2     Playground  0.0909
# 3    Candy Store  0.0909
# 4     Baby Store  0.0909
#
#
# ----Church and Wellesley----
#                  venue    freq
# 0          Coffee Shop  0.1111
# 1  Japanese Restaurant  0.0494
# 2           Restaurant  0.0494
# 3              Gay Bar  0.0494
# 4     Sushi Restaurant  0.0370
#
#
# ----Clairlea, Golden Mile, Oakridge----
#            venue  freq
# 0       Bus Line   0.2
# 1         Bakery   0.2
# 2   Intersection   0.2
# 3  Metro Station   0.1
# 4   Soccer Field   0.1
#
#
# ----Clarks Corners, Sullivan, Tam O'Shanter----
#                 venue    freq
# 0         Pizza Place  0.1667
# 1          Hobby Shop  0.0833
# 2            Bus Stop  0.0833
# 3  Chinese Restaurant  0.0833
# 4         Golf Course  0.0833
#
#
# ----Cliffcrest, Cliffside, Scarborough Village West----
#             venue    freq
# 0  Sandwich Place  0.1429
# 1        Pharmacy  0.1429
# 2     Flower Shop  0.1429
# 3    Liquor Store  0.1429
# 4     Coffee Shop  0.1429
#
#
# ----Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park----
#                      venue  freq
# 0      Filipino Restaurant   0.5
# 1               Print Shop   0.5
# 2              Yoga Studio   0.0
# 3      Monument / Landmark   0.0
# 4  New American Restaurant   0.0
#
#
# ----Commerce Court, Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                 Café  0.06
# 2                Hotel  0.06
# 3           Restaurant  0.05
# 4  Japanese Restaurant  0.04
#
#
# ----Davisville----
#                venue   freq
# 0               Park  0.375
# 1  Convenience Store  0.250
# 2     Breakfast Spot  0.125
# 3      Grocery Store  0.125
# 4               Bank  0.125
#
#
# ----Davisville North----
#                venue   freq
# 0               Park  0.375
# 1  Convenience Store  0.250
# 2     Breakfast Spot  0.125
# 3      Grocery Store  0.125
# 4               Bank  0.125
#
#
# ----Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West----
#                venue   freq
# 0               Park  0.375
# 1  Convenience Store  0.250
# 2     Breakfast Spot  0.125
# 3      Grocery Store  0.125
# 4               Bank  0.125
#
#
# ----Del Ray, Keelesdale, Mount Dennis, Silverthorn----
#                         venue  freq
# 0                  Playground  0.25
# 1  Construction & Landscaping  0.25
# 2        Fast Food Restaurant  0.25
# 3                 Coffee Shop  0.25
# 4               Movie Theater  0.00
#
#
# ----Design Exchange, Toronto Dominion Centre----
#          venue  freq
# 0  Coffee Shop  0.12
# 1         Café  0.08
# 2        Hotel  0.07
# 3   Restaurant  0.05
# 4          Bar  0.04
#
#
# ----Don Mills North----
#            venue    freq
# 0    Gas Station  0.3333
# 1   Burger Joint  0.3333
# 2           Park  0.3333
# 3    Yoga Studio  0.0000
# 4  Movie Theater  0.0000
#
#
# ----Dorset Park, Scarborough Town Centre, Wexford Heights----
#             venue    freq
# 0          Bakery  0.3333
# 1       Gift Shop  0.3333
# 2  Shipping Store  0.3333
# 3   Moving Target  0.0000
# 4       Nightclub  0.0000
#
#
# ----Dovercourt Village, Dufferin----
#                     venue    freq
# 0  Furniture / Home Store  0.1176
# 1                    Park  0.1176
# 2                    Bank  0.0588
# 3               Pet Store  0.0588
# 4                     Bar  0.0588
#
#
# ----Downsview Central----
#                        venue  freq
# 0           Business Service   1.0
# 1                Yoga Studio   0.0
# 2               Noodle House   0.0
# 3         Mexican Restaurant   0.0
# 4  Middle Eastern Restaurant   0.0
#
#
# ----Downsview Northwest----
#                   venue    freq
# 0           Pizza Place  0.0952
# 1         Shopping Mall  0.0952
# 2  Fast Food Restaurant  0.0952
# 3         Grocery Store  0.0952
# 4        Discount Store  0.0952
#
#
# ----Downsview West----
#             venue    freq
# 0          Bakery  0.0714
# 1      Beer Store  0.0714
# 2  Clothing Store  0.0714
# 3            Bank  0.0714
# 4     Coffee Shop  0.0714
#
#
# ----Downsview, North Park, Upwood Park----
#                      venue  freq
# 0                   Bakery   0.5
# 1                     Park   0.5
# 2              Yoga Studio   0.0
# 3            Movie Theater   0.0
# 4  New American Restaurant   0.0
#
#
# ----East Birchmount Park, Ionview, Kennedy Park----
#                 venue    freq
# 0      Discount Store  0.2857
# 1          Hobby Shop  0.1429
# 2         Coffee Shop  0.1429
# 3   Convenience Store  0.1429
# 4  Chinese Restaurant  0.1429
#
#
# ----East Toronto----
#                 venue  freq
# 0                Park   0.2
# 1                 Bar   0.2
# 2         Music Venue   0.2
# 3  Italian Restaurant   0.2
# 4      Farmers Market   0.2
#
#
# ----Emery, Humberlea----
#                      venue    freq
# 0              Coffee Shop  0.6667
# 1                Nightclub  0.3333
# 2      Monument / Landmark  0.0000
# 3  New American Restaurant  0.0000
# 4              Music Venue  0.0000
#
#
# ----Fairview, Henry Farm, Oriole----
#                   venue    freq
# 0        Clothing Store  0.1887
# 1  Fast Food Restaurant  0.0943
# 2         Women's Store  0.0566
# 3           Coffee Shop  0.0566
# 4              Tea Room  0.0566
#
#
# ----First Canadian Place, Underground city----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1                 Café  0.07
# 2                Hotel  0.07
# 3  American Restaurant  0.04
# 4           Restaurant  0.04
#
#
# ----Flemingdon Park, Don Mills South----
#              venue    freq
# 0  Bubble Tea Shop  0.1429
# 1    Grocery Store  0.1429
# 2       Beer Store  0.1429
# 3      Supermarket  0.1429
# 4      Coffee Shop  0.1429
#
#
# ----Forest Hill North, Forest Hill West----
#                venue   freq
# 0               Park  0.375
# 1  Convenience Store  0.250
# 2     Breakfast Spot  0.125
# 3      Grocery Store  0.125
# 4               Bank  0.125
#
#
# ----Glencairn----
#                       venue    freq
# 0               Pizza Place  0.2308
# 1      Fast Food Restaurant  0.1538
# 2  Mediterranean Restaurant  0.0769
# 3          Asian Restaurant  0.0769
# 4          Sushi Restaurant  0.0769
#
#
# ----Guildwood, Morningside, West Hill----
#                         venue    freq
# 0  Construction & Landscaping  0.3333
# 1        Gym / Fitness Center  0.3333
# 2                        Park  0.3333
# 3                 Yoga Studio  0.0000
# 4               Movie Theater  0.0000
#
#
# ----Harbord, University of Toronto----
#          venue    freq
# 0         Café  0.1034
# 1  Coffee Shop  0.0690
# 2       Bakery  0.0517
# 3   Restaurant  0.0517
# 4    Bookstore  0.0345
#
#
# ----Harbourfront----
#          venue    freq
# 0  Coffee Shop  0.1667
# 1  Pizza Place  0.0556
# 2         Park  0.0556
# 3   Restaurant  0.0556
# 4     Pharmacy  0.0278
#
#
# ----Harbourfront East, Toronto Islands, Union Station----
#                  venue    freq
# 0      Harbor / Marina  0.3333
# 1                 Pier  0.3333
# 2                 Park  0.3333
# 3          Yoga Studio  0.0000
# 4  Monument / Landmark  0.0000
#
#
# ----High Park, The Junction South----
#                      venue  freq
# 0        Convenience Store   0.5
# 1                     Park   0.5
# 2              Yoga Studio   0.0
# 3      Monument / Landmark   0.0
# 4  New American Restaurant   0.0
#
#
# ----Highland Creek, Rouge Hill, Port Union----
#                         venue    freq
# 0  Construction & Landscaping  0.3333
# 1                         Bar  0.3333
# 2               Moving Target  0.3333
# 3                 Yoga Studio  0.0000
# 4               Movie Theater  0.0000
#
#
# ----Hillcrest Village----
#                                       venue  freq
# 0                                   Dog Run   0.5
# 1  Residential Building (Apartment / Condo)   0.5
# 2                             Movie Theater   0.0
# 3                                 Nightclub   0.0
# 4                   New American Restaurant   0.0
#
#
# ----Humber Bay Shores, Mimico South, New Toronto----
#                venue   freq
# 0  Convenience Store  0.250
# 1  Indian Restaurant  0.125
# 2         Beer Store  0.125
# 3      Grocery Store  0.125
# 4               Bank  0.125
#
#
# ----Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea----
#                   venue  freq
# 0    Chinese Restaurant   0.2
# 1           Coffee Shop   0.2
# 2      Sushi Restaurant   0.2
# 3  Fast Food Restaurant   0.2
# 4    Italian Restaurant   0.2
#
#
# ----Humber Summit----
#                      venue  freq
# 0             Home Service  0.25
# 1      Rental Car Location  0.25
# 2   Furniture / Home Store  0.25
# 3         Business Service  0.25
# 4  New American Restaurant  0.00
#
#
# ----Humewood-Cedarvale----
#            venue    freq
# 0   Hockey Arena  0.1667
# 1          Trail  0.1667
# 2           Park  0.1667
# 3  Grocery Store  0.1667
# 4    Coffee Shop  0.1667
#
#
# ----Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips----
#                  venue  freq
# 0  Arts & Crafts Store  0.25
# 1          Pizza Place  0.25
# 2          Music Venue  0.25
# 3             Bus Line  0.25
# 4          Yoga Studio  0.00
#
#
# ----Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor----
#             venue    freq
# 0   Burrito Place  0.1579
# 1            Bank  0.0526
# 2             Gym  0.0526
# 3    Burger Joint  0.0526
# 4  Mattress Store  0.0526
#
#
# ----L'Amoreaux West----
#                   venue    freq
# 0  Fast Food Restaurant  0.1538
# 1    Chinese Restaurant  0.1538
# 2         Grocery Store  0.0769
# 3       Bubble Tea Shop  0.0769
# 4  Other Great Outdoors  0.0769
#
#
# ----Lawrence Heights, Lawrence Manor----
#                     venue    freq
# 0          Clothing Store  0.2264
# 1  Furniture / Home Store  0.0377
# 2     American Restaurant  0.0377
# 3        Toy / Game Store  0.0377
# 4          Cosmetics Shop  0.0377
#
#
# ----Lawrence Park----
#                venue   freq
# 0               Park  0.375
# 1  Convenience Store  0.250
# 2     Breakfast Spot  0.125
# 3      Grocery Store  0.125
# 4               Bank  0.125
#
#
# ----Leaside----
#                     venue    freq
# 0     Sporting Goods Shop  0.0811
# 1             Coffee Shop  0.0811
# 2  Furniture / Home Store  0.0541
# 3              Sports Bar  0.0541
# 4            Burger Joint  0.0541
#
#
# ----Little Portugal, Trinity----
#               venue    freq
# 0               Bar  0.0714
# 1       Coffee Shop  0.0536
# 2        Restaurant  0.0536
# 3      Cocktail Bar  0.0536
# 4  Asian Restaurant  0.0536
#
#
# ----Maryvale, Wexford----
#                      venue  freq
# 0              Auto Garage   1.0
# 1              Yoga Studio   0.0
# 2            Movie Theater   0.0
# 3                Nightclub   0.0
# 4  New American Restaurant   0.0
#
#
# ----Moore Park, Summerhill East----
#                venue   freq
# 0               Park  0.375
# 1  Convenience Store  0.250
# 2     Breakfast Spot  0.125
# 3      Grocery Store  0.125
# 4               Bank  0.125
#
#
# ----Newtonbrook, Willowdale----
#                        venue    freq
# 0  Middle Eastern Restaurant  0.0909
# 1          Korean Restaurant  0.0909
# 2                       Café  0.0909
# 3                 Hookah Bar  0.0455
# 4                Supermarket  0.0455
#
#
# ----North Toronto West----
#                venue   freq
# 0               Park  0.375
# 1  Convenience Store  0.250
# 2     Breakfast Spot  0.125
# 3      Grocery Store  0.125
# 4               Bank  0.125
#
#
# ----Northwest----
#                        venue    freq
# 0  Middle Eastern Restaurant  0.1429
# 1             Sandwich Place  0.1429
# 2                Gas Station  0.1429
# 3                Coffee Shop  0.1429
# 4           Storage Facility  0.1429
#
#
# ----Northwood Park, York University----
#                     venue    freq
# 0  Furniture / Home Store  0.2727
# 1                     Bar  0.0909
# 2     Japanese Restaurant  0.0909
# 3      Miscellaneous Shop  0.0909
# 4    Caribbean Restaurant  0.0909
#
#
# ----Parkdale, Roncesvalles----
#                          venue    freq
# 0                  Coffee Shop  0.0833
# 1                   Restaurant  0.0625
# 2  Eastern European Restaurant  0.0625
# 3                    Gift Shop  0.0417
# 4                    Bookstore  0.0417
#
#
# ----Parkwoods----
#                      venue  freq
# 0        Food & Drink Shop   0.5
# 1                     Park   0.5
# 2              Yoga Studio   0.0
# 3      Monument / Landmark   0.0
# 4  New American Restaurant   0.0
#
#
# ----Queen's Park----
#             venue    freq
# 0     Coffee Shop  0.2951
# 1  Sandwich Place  0.0984
# 2            Café  0.0656
# 3        Pharmacy  0.0492
# 4            Park  0.0492
#
#
# ----Rosedale----
#                   venue  freq
# 0            Playground   0.2
# 1         Grocery Store   0.2
# 2           Candy Store   0.2
# 3                  Park   0.2
# 4  Gym / Fitness Center   0.2
#
#
# ----Roselawn----
#                venue   freq
# 0               Park  0.375
# 1  Convenience Store  0.250
# 2     Breakfast Spot  0.125
# 3      Grocery Store  0.125
# 4               Bank  0.125
#
#
# ----Rouge, Malvern----
#                        venue  freq
# 0                  Pet Store   1.0
# 1                Yoga Studio   0.0
# 2               Noodle House   0.0
# 3         Mexican Restaurant   0.0
# 4  Middle Eastern Restaurant   0.0
#
#
# ----Runnymede, Swansea----
#           venue    freq
# 0   Pizza Place  0.0833
# 1     Pet Store  0.0833
# 2  Soccer Field  0.0833
# 3    Food Truck  0.0833
# 4          Café  0.0833
#
#
# ----Ryerson, Garden District----
#                        venue  freq
# 0                Coffee Shop  0.10
# 1             Clothing Store  0.06
# 2             Cosmetics Shop  0.04
# 3  Middle Eastern Restaurant  0.03
# 4       Fast Food Restaurant  0.03
#
#
# ----Scarborough Village----
#                      venue  freq
# 0            Train Station  0.25
# 1            Grocery Store  0.25
# 2               Restaurant  0.25
# 3        Indian Restaurant  0.25
# 4  New American Restaurant  0.00
#
#
# ----St. James Town----
#                 venue  freq
# 0         Coffee Shop  0.06
# 1                Café  0.06
# 2          Restaurant  0.05
# 3  Seafood Restaurant  0.04
# 4      Clothing Store  0.04
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#          venue  freq
# 0  Coffee Shop  0.10
# 1         Café  0.04
# 2   Steakhouse  0.04
# 3          Bar  0.04
# 4        Hotel  0.04
#
#
# ----Studio District----
#          venue    freq
# 0          Bar  0.0698
# 1  Coffee Shop  0.0698
# 2       Bakery  0.0465
# 3         Park  0.0465
# 4      Brewery  0.0465
#
#
# ----The Annex, North Midtown, Yorkville----
#                venue   freq
# 0               Park  0.375
# 1  Convenience Store  0.250
# 2     Breakfast Spot  0.125
# 3      Grocery Store  0.125
# 4               Bank  0.125
#
#
# ----The Beaches----
#                  venue  freq
# 0                 Park  0.25
# 1      Thai Restaurant  0.25
# 2                Diner  0.25
# 3   Photography Studio  0.25
# 4  Monument / Landmark  0.00
#
#
# ----The Beaches West, India Bazaar----
#                 venue    freq
# 0                Park  0.0952
# 1      Sandwich Place  0.0952
# 2  Italian Restaurant  0.0476
# 3    Sushi Restaurant  0.0476
# 4          Steakhouse  0.0476
#
#
# ----The Danforth West, Riverdale----
#             venue  freq
# 0            Park   0.2
# 1   Grocery Store   0.2
# 2  Discount Store   0.2
# 3        Bus Line   0.2
# 4      Restaurant   0.2
#
#
# ----The Junction North, Runnymede----
#                      venue    freq
# 0                  Brewery  0.5000
# 1   Furniture / Home Store  0.3333
# 2       Athletics & Sports  0.1667
# 3             Noodle House  0.0000
# 4  New American Restaurant  0.0000
#
#
# ----The Kingsway, Montgomery Road, Old Mill North----
#            venue  freq
# 0           Pool   0.5
# 1         Lounge   0.5
# 2    Yoga Studio   0.0
# 3  Movie Theater   0.0
# 4      Nightclub   0.0
#
#
# ----Thorncliffe Park----
#                  venue   freq
# 0          Yoga Studio  0.125
# 1  Housing Development  0.125
# 2          Gas Station  0.125
# 3       Sandwich Place  0.125
# 4                 Park  0.125
#
#
# ----Victoria Village----
#                      venue    freq
# 0            Grocery Store  0.3333
# 1               Food Stand  0.3333
# 2                     Park  0.3333
# 3      Monument / Landmark  0.0000
# 4  New American Restaurant  0.0000
#
#
# ----Westmount----
#                        venue    freq
# 0                Pizza Place  0.3333
# 1  Middle Eastern Restaurant  0.1667
# 2             Sandwich Place  0.1667
# 3         Chinese Restaurant  0.1667
# 4                Coffee Shop  0.1667
#
#
# ----Weston----
#                venue    freq
# 0  Convenience Store  0.1429
# 1        Pizza Place  0.1429
# 2               Café  0.1429
# 3           Pharmacy  0.1429
# 4              Diner  0.1429
#
#
# ----Willowdale South----
#                   venue    freq
# 0           Coffee Shop  0.1034
# 1      Ramen Restaurant  0.0690
# 2  Fast Food Restaurant  0.0690
# 3                  Café  0.0690
# 4       Bubble Tea Shop  0.0345
#
#
# ----Willowdale West----
#                          venue    freq
# 0            Convenience Store  0.1429
# 1                  Coffee Shop  0.1429
# 2  Eastern European Restaurant  0.1429
# 3                     Bus Line  0.1429
# 4                         Park  0.1429
#
#
# ----Woburn----
#                venue  freq
# 0        Coffee Shop  0.25
# 1  Korean Restaurant  0.25
# 2               Park  0.25
# 3   Business Service  0.25
# 4             Office  0.00
#
#
# ----Woodbine Gardens, Parkview Hill----
#                   venue    freq
# 0  Fast Food Restaurant  0.1333
# 1           Pizza Place  0.1333
# 2             Gastropub  0.0667
# 3             Pet Store  0.0667
# 4    Rock Climbing Spot  0.0667
#
#
# ----Woodbine Heights----
#                        venue    freq
# 0                   Bus Line  0.0870
# 1              Grocery Store  0.0870
# 2                Pizza Place  0.0870
# 3                   Pharmacy  0.0870
# 4  Middle Eastern Restaurant  0.0435
#
#
# ----York Mills West----
#                venue  freq
# 0          Speakeasy  0.25
# 1               Bank  0.25
# 2  Convenience Store  0.25
# 3               Park  0.25
# 4      Movie Theater  0.00

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    y=[]
    for n in range (0,num_top_venues):  # I added this modification because some areas don't have many venues
        if row_categories_sorted[n] == 0:
            y.append('')
        else:
            y.append(row_categories_sorted.index.values[n])
    return y 

num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(20)
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 0                            Adelaide, King, Richmond           Coffee Shop
# 1                                           Agincourt           Supermarket
# 2   Agincourt North, L'Amoreaux East, Milliken, St...              Pharmacy
# 3   Albion Gardens, Beaumond Heights, Humbergate, ...         Grocery Store
# 4                              Alderwood, Long Branch                   Pub
# 5     Bathurst Manor, Downsview North, Wilson Heights           Men's Store
# 6                                     Bayview Village                 Trail
# 7                   Bedford Park, Lawrence Manor East           Coffee Shop
# 8                                         Berczy Park           Coffee Shop
# 9                         Birch Cliff, Cliffside West       College Stadium
# 10  Bloordale Gardens, Eringate, Markland Wood, Ol...     Fish & Chips Shop
# 11       Brockton, Exhibition Place, Parkdale Village           Coffee Shop
# 12  Business Reply Mail Processing Centre 969 Eastern           Coffee Shop
# 13                        CFB Toronto, Downsview East           Coffee Shop
# 14  CN Tower, Bathurst Quay, Island airport, Harbo...           Coffee Shop
# 15                        Cabbagetown, St. James Town           Coffee Shop
# 16                                Caledonia-Fairbanks                  Park
# 17              Canada Post Gateway Processing Centre                 Hotel
# 18                                          Cedarbrae            Playground
# 19                                 Central Bay Street           Coffee Shop
#
#    2nd Most Common Venue       3rd Most Common Venue 4th Most Common Venue  \
# 0                   Café                       Hotel            Steakhouse
# 1          Shopping Mall         Shanghai Restaurant                Bakery
# 2
# 3            Coffee Shop              Hardware Store           Pizza Place
# 4                    Gym                Dance Studio     Convenience Store
# 5
# 6                Dog Run  Construction & Landscaping                  Park
# 7     Italian Restaurant            Sushi Restaurant            Hobby Shop
# 8             Restaurant                        Café           Cheese Shop
# 9               Gym Pool                         Gym          Skating Rink
# 10         Shopping Mall                Carpet Store    College Rec Center
# 11                  Café      Furniture / Home Store            Restaurant
# 12                 Hotel                        Café                   Bar
# 13                  Park                     Airport            Food Court
# 14                 Hotel            Sushi Restaurant            Restaurant
# 15            Restaurant                      Bakery           Pizza Place
# 16         Women's Store        Fast Food Restaurant    Mexican Restaurant
# 17           Coffee Shop              Sandwich Place                   Gym
# 18                 Trail
# 19        Clothing Store        Fast Food Restaurant        Cosmetics Shop
#
#     5th Most Common Venue
# 0               Gastropub
# 1        Sushi Restaurant
# 2
# 3             Video Store
# 4          Sandwich Place
# 5
# 6      Golf Driving Range
# 7       Indian Restaurant
# 8              Steakhouse
# 9   General Entertainment
# 10          Grocery Store
# 11                 Bakery
# 12             Steakhouse
# 13
# 14      French Restaurant
# 15                   Café
# 16    Sporting Goods Shop
# 17               Pharmacy
# 18
# 19               Tea Room

# %%
from sklearn.cluster import KMeans

# set number of clusters. I increased the number of clusters to make the map more interesting
kclusters = 10

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:100]
# Out:
# array([0, 0, 4, 3, 3, 9, 3, 0, 0, 3, 0, 0, 0, 3, 0, 0, 3, 0, 3, 0, 0, 0,
#        0, 0, 0, 3, 3, 0, 1, 1, 1, 3, 0, 1, 0, 0, 7, 0, 0, 1, 3, 0, 3, 0,
#        0, 3, 1, 0, 6, 0, 0, 1, 1, 0, 5, 3, 0, 3, 3, 0, 0, 0, 0, 1, 0, 0,
#        2, 1, 0, 1, 3, 3, 0, 1, 3, 3, 1, 8, 0, 0, 3, 0, 0, 0, 1, 3, 0, 3,
#        3, 0, 3, 1, 0, 0, 0, 3, 3, 0, 0, 1], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = ton2

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head(10)
# Out:
#   PostalCode      Borough                                     Neighborhood  \
# 0        M1B  Scarborough                                   Rouge, Malvern
# 1        M1C  Scarborough           Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough                Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                           Woburn
# 4        M1H  Scarborough                                        Cedarbrae
# 5        M1J  Scarborough                              Scarborough Village
# 6        M1K  Scarborough      East Birchmount Park, Ionview, Kennedy Park
# 7        M1L  Scarborough                  Clairlea, Golden Mile, Oakridge
# 8        M1M  Scarborough  Cliffcrest, Cliffside, Scarborough Village West
# 9        M1N  Scarborough                      Birch Cliff, Cliffside West
#
#     Latitude  Longitude  Cluster Labels       1st Most Common Venue  \
# 0  43.811525 -79.195517             8.0                   Pet Store
# 1  43.785665 -79.158725             0.0  Construction & Landscaping
# 2  43.765815 -79.175193             6.0                        Park
# 3  43.768369 -79.217590             3.0                        Park
# 4  43.769688 -79.239440             3.0                  Playground
# 5  43.743125 -79.231750             3.0                  Restaurant
# 6  43.726276 -79.263625             3.0              Discount Store
# 7  43.713054 -79.285055             0.0                      Bakery
# 8  43.724235 -79.227925             3.0              Sandwich Place
# 9  43.696770 -79.259967             3.0             College Stadium
#
#         2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0
# 1               Moving Target                   Bar
# 2  Construction & Landscaping  Gym / Fitness Center
# 3           Korean Restaurant      Business Service           Coffee Shop
# 4                       Trail
# 5           Indian Restaurant         Grocery Store         Train Station
# 6                 Coffee Shop      Department Store    Chinese Restaurant
# 7                    Bus Line          Intersection           Bus Station
# 8                        Bank              Pharmacy           Flower Shop
# 9                    Gym Pool                   Gym          Skating Rink
#
#    5th Most Common Venue
# 0
# 1
# 2
# 3
# 4
# 5
# 6             Hobby Shop
# 7           Soccer Field
# 8           Liquor Store
# 9  General Entertainment

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
import math
import folium

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    if not math.isnan(cluster): # two neighborhoods had no finding and weren't classified
        label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup=label,
            color=rainbow[int(cluster)-1],
            fill=True,
            fill_color=rainbow[int(cluster)-1],
            fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# If the map doesn't display, here is a example of the output
#
# ![Sample Map](map.png "Sample Map")
